# %%
#cài đặt các thư viện cần thiết
#diffuser: thư viện hỗ trợ các pipeline khuyếch tán như diffusion
#accelerate: tối ưu hóa huấn luyện và sử dụng mô hình trên phần cứng (CPU/GPU)
# %%capture

# 1 dòng code tại đây

# %%
## Import thư viện torch và DiffusionPipeline từ diffusers
#Mục đích:
#torch: Thư viện quan trọng của PyTorch để làm việc với tensor, tính toán GPU.
#DiffusionPipeline: dùng để tải và sử dụng pipeline khuếch tán (diffusion).


# 2 dòng code tại đây

# %%
# Khởi tạo stable diffusion
# Định nghĩa pipleline cho stable diffusion
#Tải mô hình được huấn luyện trước từ CompVis/stable-diffusion-v1-4, chú ý sử dụng from_pretrained()
#torch_dtype=torch.float16: Sử dụng định dạng float16 để giảm bộ nhớ và tăng tốc tính toán.


pipeline2 = #code tại đây

# Đặt thiết bị cho pipeline
# .to("cuda"): Chuyển pipeline sang GPU (CUDA) để xử lý nhanh hơn.

pipeline2 = #code tại đây
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
# Đặt seed để đảm bảo tái hiện được kết quả thí nghiệm
#sử dụng:
     # torch.Generator: Tạo bộ sinh số ngẫu nhiên cho PyTorch.
     #.manual_seed(42): Đặt giá trị seed là 42 để đảm bảo rằng kết quả mỗi lần chạy giống nhau.

generator = #code tại đây

# %%
# Đặt prompt (văn bản đầu vào)
    #prompt: Văn bản miêu tả hình ảnh cần tạo.
    #ví dụ:
prompt = "baby in soccer player's shirt"
# Đặt negative prompt (nếu không cần thì để None)
    #negative_prompt: Miêu tả các đặc điểm cần tránh trong hình ảnh (có thể để None nếu không cần).
negative_prompt = None
# Thực thi pipeline để tạo hình ảnh với các tham số đầu vào
     #prompt
     #negative_prompt
     #generator được nhận từ cell trước
     #height/width: kích thước hình ảnh tạo ra (ví dụ 1024*1024)

image = pipeline2(#code tại đây)

#sử dụng .images[0] để lấy hình ảnh đầu tiên được tạo ra từ pipeline

# 1 dòng code tại đây
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %%
#làm tương tự như trên nhưng ở đây load mô hình khác được huấn luận trước
#sử dụng stabilityai/stable-diffusion-xl-base-1.0 để đạt hiệu quả tốt hơn


#Đoạn code thiết kế pipeline tương tự trên
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
#Đoạn code load các prompt, negative prompt, generator, height, width tương tự trên
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
#code hiển thị ảnh
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %%
#Vẫn sử dụng  stabilityai/stable-diffusion-xl-base-1.0
#Nhưng ta thử cải thiện ảnh đầu ra với việc thay đổi prompt

#Ví dụ prompt bây giờ là: "baby in soccer player's shirt, photorealistic, cinematic, ultra detailed"


#Viết đoạn code thực thi yêu cầu trên, và hiển thị kết quả
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=1024x1024>
